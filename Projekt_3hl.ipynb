# %%
import os
from PIL import Image
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms, datasets, utils
from PIL import Image
import os
import itertools
from torchvision.utils import make_grid
import matplotlib.pyplot as plt

# %%
root_dir = "data"

# %%
image_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff', '.gif')

# %%
# Iterate over class folders in the data directory
for class_name in os.listdir(root_dir):
    class_path = os.path.join(root_dir, class_name)
    if os.path.isdir(class_path):
        print(f"Class: {class_name}")
        # Walk through all subdirectories
        for subdir, _, files in os.walk(class_path):
            resolution_count = {}
            total_images = 0
            for file in files:
                if file.lower().endswith(image_extensions):
                    try:
                        img_path = os.path.join(subdir, file)
                        with Image.open(img_path) as img:
                            resolution = img.size  # (width, height)
                            resolution_count[resolution] = resolution_count.get(resolution, 0) + 1
                            total_images += 1
                    except Exception as e:
                        print(f"Error opening {file}: {e}")
            if total_images > 0:
                subfolder_name = os.path.relpath(subdir, class_path)
                print(f"  Subfolder: {subfolder_name}")
                for res, count in resolution_count.items():
                    print(f"    Resolution: {res}, Count: {count}")
# Out:
# Class: apple2orange
#   Subfolder: apple2orange\testA
#     Resolution: (256, 256), Count: 266
#   Subfolder: apple2orange\testB
#     Resolution: (256, 256), Count: 248
#   Subfolder: apple2orange\trainA
#     Resolution: (256, 256), Count: 995
#   Subfolder: apple2orange\trainB
#     Resolution: (256, 256), Count: 1019
# Class: horse2zebra
#   Subfolder: horse2zebra\testA
#     Resolution: (256, 256), Count: 120
#   Subfolder: horse2zebra\testB
#     Resolution: (256, 256), Count: 140
#   Subfolder: horse2zebra\trainA
#     Resolution: (256, 256), Count: 1067
#   Subfolder: horse2zebra\trainB
#     Resolution: (256, 256), Count: 1334

# %% [markdown]
# Triedy ktoré nemajú konzistentné rozlíšenie:cityscapes,iphone2dslr_flower,maps,

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

print(device)
# Out:
# cuda

# %% [markdown]
# ## Hyperparametre

# %%
IMG_SIZE = 64
BATCH_SIZE = 32
LR = 0.0002
EPOCHS = 200
LAMBDA_CYCLE = 10.0
LAMBDA_IDENTITY = 5.0

# %%
class ImageDataset(Dataset):
    def __init__(self, root, transform=None, mode='train', max_samples=None):
        self.transform = transform
        self.root = root
        self.mode = mode
        self.files_A = sorted(os.listdir(os.path.join(root, f"{mode}A")))
        self.files_B = sorted(os.listdir(os.path.join(root, f"{mode}B")))
        if max_samples:
            self.files_A = self.files_A[:max_samples]
            self.files_B = self.files_B[:max_samples]
        self.path_A = os.path.join(root, f"{mode}A")
        self.path_B = os.path.join(root, f"{mode}B")

    def __getitem__(self, index):
        img_A = Image.open(os.path.join(self.path_A, self.files_A[index % len(self.files_A)])).convert("RGB")
        img_B = Image.open(os.path.join(self.path_B, self.files_B[index % len(self.files_B)])).convert("RGB")

        if self.transform:
            img_A = self.transform(img_A)
            img_B = self.transform(img_B)

        return {"A": img_A, "B": img_B}

    def __len__(self):
        return max(len(self.files_A), len(self.files_B))

# %%
transform = transforms.Compose([
    transforms.Resize(IMG_SIZE),
    transforms.CenterCrop(IMG_SIZE),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# %% [markdown]
# ### Generator

# %%
# models.py
class ResidualBlock(nn.Module):
    def __init__(self, channels):
        super().__init__()
        self.block = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(channels, channels, kernel_size=3),
            nn.InstanceNorm2d(channels),
            nn.ReLU(inplace=True),
            nn.ReflectionPad2d(1),
            nn.Conv2d(channels, channels, kernel_size=3),
            nn.InstanceNorm2d(channels),
        )

    def forward(self, x):
        return x + self.block(x)


class Generator(nn.Module):
    def __init__(self, in_channels=3, out_channels=3, num_residuals=6):
        super().__init__()
        model = [
            nn.ReflectionPad2d(3),
            nn.Conv2d(in_channels, 64, kernel_size=7),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True),
        ]

        # Downsampling
        in_features = 64
        out_features = in_features * 2
        for _ in range(2):  # 64 → 32 → 16
            model += [
                nn.Conv2d(in_features, out_features, kernel_size=3, stride=2, padding=1),
                nn.InstanceNorm2d(out_features),
                nn.ReLU(inplace=True),
            ]
            in_features = out_features
            out_features = in_features * 2

        # Residual blocks
        for _ in range(num_residuals):
            model += [ResidualBlock(in_features)]

        # Upsampling
        out_features = in_features // 2
        for _ in range(2):  # 16 → 32 → 64
            model += [
                nn.ConvTranspose2d(in_features, out_features, kernel_size=3, stride=2, padding=1, output_padding=1),
                nn.InstanceNorm2d(out_features),
                nn.ReLU(inplace=True),
            ]
            in_features = out_features
            out_features = in_features // 2

        model += [
            nn.ReflectionPad2d(3),
            nn.Conv2d(64, out_channels, kernel_size=7),
            nn.Tanh(),
        ]

        self.model = nn.Sequential(*model)

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Discriminator

# %%
# models.py (continued)
class Discriminator(nn.Module):
    def __init__(self, in_channels=3):
        super().__init__()
        def discriminator_block(in_filters, out_filters, normalization=True):
            layers = [nn.Conv2d(in_filters, out_filters, kernel_size=4, stride=2, padding=1)]
            if normalization:
                layers.append(nn.InstanceNorm2d(out_filters))
            layers.append(nn.LeakyReLU(0.2, inplace=True))
            return layers

        self.model = nn.Sequential(
            *discriminator_block(in_channels, 64, normalization=False),  # (64x64) -> (32x32)
            *discriminator_block(64, 128),  # -> (16x16)
            *discriminator_block(128, 256),  # -> (8x8)
            *discriminator_block(256, 512),  # -> (4x4)
            nn.Conv2d(512, 1, kernel_size=4, padding=1)  # Output patch size (3x3 or so)
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ### Loss functions

# %%
adversarial_criterion = nn.MSELoss()
cycle_criterion = nn.L1Loss()
identity_criterion = nn.L1Loss()

# %%
G_AB = Generator().to(device)
G_BA = Generator().to(device)
D_A = Discriminator().to(device)
D_B = Discriminator().to(device)

# Optimizers
g_optimizer = optim.Adam(
    itertools.chain(G_AB.parameters(), G_BA.parameters()), 
    lr=LR, betas=(0.5, 0.999)
)
d_A_optimizer = optim.Adam(D_A.parameters(), lr=LR, betas=(0.5, 0.999))
d_B_optimizer = optim.Adam(D_B.parameters(), lr=LR, betas=(0.5, 0.999))

# %% [markdown]
# ### Training loop

# %%
def train(dataloader):
    for epoch in range(EPOCHS):
        for i, batch in enumerate(dataloader):
            real_A = batch["A"].to(device)
            real_B = batch["B"].to(device)

            # -----------------------------------
            #  Train Generators G_AB and G_BA
            # -----------------------------------
            g_optimizer.zero_grad()

            # Identity loss
            same_B = G_AB(real_B)
            loss_identity_B = identity_criterion(same_B, real_B) * LAMBDA_IDENTITY

            same_A = G_BA(real_A)
            loss_identity_A = identity_criterion(same_A, real_A) * LAMBDA_IDENTITY

            # GAN loss
            fake_B = G_AB(real_A)
            pred_fake_B = D_B(fake_B)
            loss_GAN_AB = adversarial_criterion(pred_fake_B, torch.ones_like(pred_fake_B))

            fake_A = G_BA(real_B)
            pred_fake_A = D_A(fake_A)
            loss_GAN_BA = adversarial_criterion(pred_fake_A, torch.ones_like(pred_fake_A))

            # Cycle loss
            recov_A = G_BA(fake_B)
            loss_cycle_A = cycle_criterion(recov_A, real_A)

            recov_B = G_AB(fake_A)
            loss_cycle_B = cycle_criterion(recov_B, real_B)

            # Total generator loss
            g_loss = (loss_GAN_AB + loss_GAN_BA) + \
                     LAMBDA_CYCLE * (loss_cycle_A + loss_cycle_B) + \
                     (loss_identity_A + loss_identity_B)

            g_loss.backward()
            g_optimizer.step()

            # -----------------------------------
            #  Train Discriminator A
            # -----------------------------------
            d_A_optimizer.zero_grad()

            pred_real = D_A(real_A)
            loss_D_real = adversarial_criterion(pred_real, torch.ones_like(pred_real))

            pred_fake = D_A(fake_A.detach())
            loss_D_fake = adversarial_criterion(pred_fake, torch.zeros_like(pred_fake))

            d_A_loss = (loss_D_real + loss_D_fake) * 0.5
            d_A_loss.backward()
            d_A_optimizer.step()

            # -----------------------------------
            #  Train Discriminator B
            # -----------------------------------
            d_B_optimizer.zero_grad()

            pred_real = D_B(real_B)
            loss_D_real = adversarial_criterion(pred_real, torch.ones_like(pred_real))

            pred_fake = D_B(fake_B.detach())
            loss_D_fake = adversarial_criterion(pred_fake, torch.zeros_like(pred_fake))

            d_B_loss = (loss_D_real + loss_D_fake) * 0.5
            d_B_loss.backward()
            d_B_optimizer.step()

            # Logging
            if i % 100 == 0:
                print(
                    f"[Epoch {epoch}/{EPOCHS}] [Batch {i}/{len(dataloader)}] "
                    f"[D_A Loss: {d_A_loss.item():.4f}] [D_B Loss: {d_B_loss.item():.4f}] "
                    f"[G Loss: {g_loss.item():.4f}]"
                )

# %%
path_to_dataset="data/apple2orange/apple2orange"

dataset = ImageDataset(path_to_dataset, transform=transform)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)
train(dataloader)
# Out:
# [Epoch 0/200] [Batch 0/32] [D_A Loss: 0.2657] [D_B Loss: 0.2990] [G Loss: 7.4723]
# [Epoch 1/200] [Batch 0/32] [D_A Loss: 0.1983] [D_B Loss: 0.1872] [G Loss: 5.5200]
# [Epoch 2/200] [Batch 0/32] [D_A Loss: 0.2076] [D_B Loss: 0.1973] [G Loss: 5.5874]
# [Epoch 3/200] [Batch 0/32] [D_A Loss: 0.1829] [D_B Loss: 0.1760] [G Loss: 5.2864]
# [Epoch 4/200] [Batch 0/32] [D_A Loss: 0.1887] [D_B Loss: 0.1564] [G Loss: 5.1688]
# [Epoch 5/200] [Batch 0/32] [D_A Loss: 0.1694] [D_B Loss: 0.1659] [G Loss: 5.2945]
# [Epoch 6/200] [Batch 0/32] [D_A Loss: 0.1633] [D_B Loss: 0.1583] [G Loss: 4.7560]
# [Epoch 7/200] [Batch 0/32] [D_A Loss: 0.1475] [D_B Loss: 0.1391] [G Loss: 5.2102]
# [Epoch 8/200] [Batch 0/32] [D_A Loss: 0.1424] [D_B Loss: 0.1459] [G Loss: 5.5537]
# [Epoch 9/200] [Batch 0/32] [D_A Loss: 0.1764] [D_B Loss: 0.1360] [G Loss: 5.1818]
# [Epoch 10/200] [Batch 0/32] [D_A Loss: 0.1744] [D_B Loss: 0.1745] [G Loss: 4.9947]
# [Epoch 11/200] [Batch 0/32] [D_A Loss: 0.1565] [D_B Loss: 0.1316] [G Loss: 5.4793]
# [Epoch 12/200] [Batch 0/32] [D_A Loss: 0.1204] [D_B Loss: 0.1151] [G Loss: 5.0197]
# [Epoch 13/200] [Batch 0/32] [D_A Loss: 0.1226] [D_B Loss: 0.1359] [G Loss: 4.6907]
# [Epoch 14/200] [Batch 0/32] [D_A Loss: 0.1047] [D_B Loss: 0.0811] [G Loss: 5.0872]
# [Epoch 15/200] [Batch 0/32] [D_A Loss: 0.0934] [D_B Loss: 0.0904] [G Loss: 4.9454]
# [Epoch 16/200] [Batch 0/32] [D_A Loss: 0.0888] [D_B Loss: 0.1041] [G Loss: 5.5251]
# [Epoch 17/200] [Batch 0/32] [D_A Loss: 0.1094] [D_B Loss: 0.1137] [G Loss: 5.0047]
# [Epoch 18/200] [Batch 0/32] [D_A Loss: 0.1100] [D_B Loss: 0.1206] [G Loss: 5.1928]
# [Epoch 19/200] [Batch 0/32] [D_A Loss: 0.0949] [D_B Loss: 0.0841] [G Loss: 5.2870]
# [Epoch 20/200] [Batch 0/32] [D_A Loss: 0.0852] [D_B Loss: 0.0795] [G Loss: 5.0528]
# [Epoch 21/200] [Batch 0/32] [D_A Loss: 0.0867] [D_B Loss: 0.0749] [G Loss: 4.9917]
# [Epoch 22/200] [Batch 0/32] [D_A Loss: 0.0928] [D_B Loss: 0.0965] [G Loss: 5.5750]
# [Epoch 23/200] [Batch 0/32] [D_A Loss: 0.0722] [D_B Loss: 0.0747] [G Loss: 4.9314]
# [Epoch 24/200] [Batch 0/32] [D_A Loss: 0.0812] [D_B Loss: 0.0709] [G Loss: 5.2693]
# [Epoch 25/200] [Batch 0/32] [D_A Loss: 0.0801] [D_B Loss: 0.0896] [G Loss: 5.1715]
# [Epoch 26/200] [Batch 0/32] [D_A Loss: 0.0836] [D_B Loss: 0.0732] [G Loss: 5.3933]
# [Epoch 27/200] [Batch 0/32] [D_A Loss: 0.0752] [D_B Loss: 0.0484] [G Loss: 5.0942]
# [Epoch 28/200] [Batch 0/32] [D_A Loss: 0.0903] [D_B Loss: 0.0676] [G Loss: 4.9225]
# [Epoch 29/200] [Batch 0/32] [D_A Loss: 0.0692] [D_B Loss: 0.0862] [G Loss: 5.1179]
# [Epoch 30/200] [Batch 0/32] [D_A Loss: 0.0731] [D_B Loss: 0.1278] [G Loss: 5.1396]
# [Epoch 31/200] [Batch 0/32] [D_A Loss: 0.0508] [D_B Loss: 0.0725] [G Loss: 5.1746]
# [Epoch 32/200] [Batch 0/32] [D_A Loss: 0.0817] [D_B Loss: 0.0849] [G Loss: 4.7863]
# [Epoch 33/200] [Batch 0/32] [D_A Loss: 0.0506] [D_B Loss: 0.0542] [G Loss: 6.1420]
# [Epoch 34/200] [Batch 0/32] [D_A Loss: 0.0411] [D_B Loss: 0.0744] [G Loss: 5.0349]
# [Epoch 35/200] [Batch 0/32] [D_A Loss: 0.0533] [D_B Loss: 0.0651] [G Loss: 5.3290]
# [Epoch 36/200] [Batch 0/32] [D_A Loss: 0.0660] [D_B Loss: 0.0609] [G Loss: 5.0184]
# [Epoch 37/200] [Batch 0/32] [D_A Loss: 0.0538] [D_B Loss: 0.0522] [G Loss: 5.0728]
# [Epoch 38/200] [Batch 0/32] [D_A Loss: 0.0452] [D_B Loss: 0.0443] [G Loss: 4.9715]
# [Epoch 39/200] [Batch 0/32] [D_A Loss: 0.0572] [D_B Loss: 0.0583] [G Loss: 4.9657]
# [Epoch 40/200] [Batch 0/32] [D_A Loss: 0.0440] [D_B Loss: 0.1395] [G Loss: 5.7902]
# [Epoch 41/200] [Batch 0/32] [D_A Loss: 0.0803] [D_B Loss: 0.0805] [G Loss: 5.2847]
# [Epoch 42/200] [Batch 0/32] [D_A Loss: 0.0575] [D_B Loss: 0.1731] [G Loss: 5.9104]
# [Epoch 43/200] [Batch 0/32] [D_A Loss: 0.0625] [D_B Loss: 0.0928] [G Loss: 5.4681]
# [Epoch 44/200] [Batch 0/32] [D_A Loss: 0.0411] [D_B Loss: 0.0906] [G Loss: 4.8222]
# [Epoch 45/200] [Batch 0/32] [D_A Loss: 0.0635] [D_B Loss: 0.0484] [G Loss: 5.1914]
# [Epoch 46/200] [Batch 0/32] [D_A Loss: 0.0530] [D_B Loss: 0.0631] [G Loss: 5.1253]
# [Epoch 47/200] [Batch 0/32] [D_A Loss: 0.0554] [D_B Loss: 0.0648] [G Loss: 4.9896]
# [Epoch 48/200] [Batch 0/32] [D_A Loss: 0.0603] [D_B Loss: 0.0865] [G Loss: 5.5887]
# [Epoch 49/200] [Batch 0/32] [D_A Loss: 0.0401] [D_B Loss: 0.0488] [G Loss: 5.3857]
# [Epoch 50/200] [Batch 0/32] [D_A Loss: 0.0488] [D_B Loss: 0.0599] [G Loss: 4.9908]
# [Epoch 51/200] [Batch 0/32] [D_A Loss: 0.0516] [D_B Loss: 0.0387] [G Loss: 5.1741]
# [Epoch 52/200] [Batch 0/32] [D_A Loss: 0.0680] [D_B Loss: 0.0551] [G Loss: 5.3152]
# [Epoch 53/200] [Batch 0/32] [D_A Loss: 0.0727] [D_B Loss: 0.1554] [G Loss: 4.8946]
# [Epoch 54/200] [Batch 0/32] [D_A Loss: 0.0480] [D_B Loss: 0.1131] [G Loss: 4.6068]
# [Epoch 55/200] [Batch 0/32] [D_A Loss: 0.0602] [D_B Loss: 0.0474] [G Loss: 5.4815]
# [Epoch 56/200] [Batch 0/32] [D_A Loss: 0.0462] [D_B Loss: 0.0950] [G Loss: 4.8980]
# [Epoch 57/200] [Batch 0/32] [D_A Loss: 0.0403] [D_B Loss: 0.0335] [G Loss: 5.2161]
# [Epoch 58/200] [Batch 0/32] [D_A Loss: 0.0416] [D_B Loss: 0.0557] [G Loss: 4.9980]
# [Epoch 59/200] [Batch 0/32] [D_A Loss: 0.0431] [D_B Loss: 0.0450] [G Loss: 5.2834]
# [Epoch 60/200] [Batch 0/32] [D_A Loss: 0.0436] [D_B Loss: 0.0637] [G Loss: 5.4842]
# [Epoch 61/200] [Batch 0/32] [D_A Loss: 0.0582] [D_B Loss: 0.0478] [G Loss: 4.7068]
# [Epoch 62/200] [Batch 0/32] [D_A Loss: 0.0423] [D_B Loss: 0.0464] [G Loss: 5.0043]
# [Epoch 63/200] [Batch 0/32] [D_A Loss: 0.0500] [D_B Loss: 0.0602] [G Loss: 4.7894]
# [Epoch 64/200] [Batch 0/32] [D_A Loss: 0.0505] [D_B Loss: 0.0345] [G Loss: 5.0849]
# [Epoch 65/200] [Batch 0/32] [D_A Loss: 0.0587] [D_B Loss: 0.0792] [G Loss: 4.9170]
# [Epoch 66/200] [Batch 0/32] [D_A Loss: 0.0516] [D_B Loss: 0.0564] [G Loss: 5.2247]
# [Epoch 67/200] [Batch 0/32] [D_A Loss: 0.0487] [D_B Loss: 0.0409] [G Loss: 5.2858]
# [Epoch 68/200] [Batch 0/32] [D_A Loss: 0.0638] [D_B Loss: 0.0356] [G Loss: 5.6148]
# [Epoch 69/200] [Batch 0/32] [D_A Loss: 0.0382] [D_B Loss: 0.0593] [G Loss: 4.8038]
# [Epoch 70/200] [Batch 0/32] [D_A Loss: 0.0418] [D_B Loss: 0.0333] [G Loss: 5.1290]
# [Epoch 71/200] [Batch 0/32] [D_A Loss: 0.0690] [D_B Loss: 0.0439] [G Loss: 5.2339]
# [Epoch 72/200] [Batch 0/32] [D_A Loss: 0.0288] [D_B Loss: 0.0317] [G Loss: 5.4856]
# [Epoch 73/200] [Batch 0/32] [D_A Loss: 0.0336] [D_B Loss: 0.0382] [G Loss: 5.4363]
# [Epoch 74/200] [Batch 0/32] [D_A Loss: 0.0857] [D_B Loss: 0.0734] [G Loss: 4.8702]
# [Epoch 75/200] [Batch 0/32] [D_A Loss: 0.0705] [D_B Loss: 0.0567] [G Loss: 4.7424]
# [Epoch 76/200] [Batch 0/32] [D_A Loss: 0.0488] [D_B Loss: 0.0353] [G Loss: 4.7015]
# [Epoch 77/200] [Batch 0/32] [D_A Loss: 0.0309] [D_B Loss: 0.0412] [G Loss: 5.3532]
# [Epoch 78/200] [Batch 0/32] [D_A Loss: 0.0526] [D_B Loss: 0.0592] [G Loss: 5.4315]
# [Epoch 79/200] [Batch 0/32] [D_A Loss: 0.1135] [D_B Loss: 0.0349] [G Loss: 4.6347]
# [Epoch 80/200] [Batch 0/32] [D_A Loss: 0.0373] [D_B Loss: 0.0351] [G Loss: 5.2982]
# [Epoch 81/200] [Batch 0/32] [D_A Loss: 0.0332] [D_B Loss: 0.0408] [G Loss: 5.3546]
# [Epoch 82/200] [Batch 0/32] [D_A Loss: 0.0661] [D_B Loss: 0.0429] [G Loss: 4.9673]
# [Epoch 83/200] [Batch 0/32] [D_A Loss: 0.0659] [D_B Loss: 0.1110] [G Loss: 4.7261]
# [Epoch 84/200] [Batch 0/32] [D_A Loss: 0.0368] [D_B Loss: 0.0451] [G Loss: 5.0903]
# [Epoch 85/200] [Batch 0/32] [D_A Loss: 0.0275] [D_B Loss: 0.0531] [G Loss: 4.5524]
# [Epoch 86/200] [Batch 0/32] [D_A Loss: 0.0348] [D_B Loss: 0.0723] [G Loss: 5.2690]
# [Epoch 87/200] [Batch 0/32] [D_A Loss: 0.0405] [D_B Loss: 0.0455] [G Loss: 5.0213]
# [Epoch 88/200] [Batch 0/32] [D_A Loss: 0.0471] [D_B Loss: 0.0360] [G Loss: 5.2261]
# [Epoch 89/200] [Batch 0/32] [D_A Loss: 0.1190] [D_B Loss: 0.0263] [G Loss: 4.5232]
# [Epoch 90/200] [Batch 0/32] [D_A Loss: 0.0366] [D_B Loss: 0.0251] [G Loss: 5.1568]
# [Epoch 91/200] [Batch 0/32] [D_A Loss: 0.0519] [D_B Loss: 0.0289] [G Loss: 4.7986]
# [Epoch 92/200] [Batch 0/32] [D_A Loss: 0.0422] [D_B Loss: 0.0286] [G Loss: 4.8175]
# [Epoch 93/200] [Batch 0/32] [D_A Loss: 0.4865] [D_B Loss: 0.0424] [G Loss: 5.3554]
# [Epoch 94/200] [Batch 0/32] [D_A Loss: 0.0569] [D_B Loss: 0.0913] [G Loss: 4.4888]
# [Epoch 95/200] [Batch 0/32] [D_A Loss: 0.0534] [D_B Loss: 0.0399] [G Loss: 5.0749]
# [Epoch 96/200] [Batch 0/32] [D_A Loss: 0.0319] [D_B Loss: 0.0314] [G Loss: 5.1140]
# [Epoch 97/200] [Batch 0/32] [D_A Loss: 0.0219] [D_B Loss: 0.0333] [G Loss: 4.7462]
# [Epoch 98/200] [Batch 0/32] [D_A Loss: 0.0288] [D_B Loss: 0.0231] [G Loss: 5.1354]
# [Epoch 99/200] [Batch 0/32] [D_A Loss: 0.0247] [D_B Loss: 0.0527] [G Loss: 4.7765]
# [Epoch 100/200] [Batch 0/32] [D_A Loss: 0.0343] [D_B Loss: 0.1459] [G Loss: 4.4443]
# [Epoch 101/200] [Batch 0/32] [D_A Loss: 0.0303] [D_B Loss: 0.0362] [G Loss: 5.1505]
# [Epoch 102/200] [Batch 0/32] [D_A Loss: 0.0374] [D_B Loss: 0.0319] [G Loss: 4.9459]
# [Epoch 103/200] [Batch 0/32] [D_A Loss: 0.0400] [D_B Loss: 0.0350] [G Loss: 5.5331]
# [Epoch 104/200] [Batch 0/32] [D_A Loss: 0.0306] [D_B Loss: 0.0326] [G Loss: 5.2914]
# [Epoch 105/200] [Batch 0/32] [D_A Loss: 0.0409] [D_B Loss: 0.2557] [G Loss: 4.2953]
# [Epoch 106/200] [Batch 0/32] [D_A Loss: 0.0485] [D_B Loss: 0.0485] [G Loss: 4.6949]
# [Epoch 107/200] [Batch 0/32] [D_A Loss: 0.0811] [D_B Loss: 0.0309] [G Loss: 4.5454]
# [Epoch 108/200] [Batch 0/32] [D_A Loss: 0.0482] [D_B Loss: 0.0251] [G Loss: 4.8040]
# [Epoch 109/200] [Batch 0/32] [D_A Loss: 0.0293] [D_B Loss: 0.0391] [G Loss: 5.3363]
# [Epoch 110/200] [Batch 0/32] [D_A Loss: 0.0352] [D_B Loss: 0.0519] [G Loss: 4.8276]
# [Epoch 111/200] [Batch 0/32] [D_A Loss: 0.0502] [D_B Loss: 0.0313] [G Loss: 4.6283]
# [Epoch 112/200] [Batch 0/32] [D_A Loss: 0.0468] [D_B Loss: 0.0379] [G Loss: 4.9755]
# [Epoch 113/200] [Batch 0/32] [D_A Loss: 0.0726] [D_B Loss: 0.0384] [G Loss: 4.6027]
# [Epoch 114/200] [Batch 0/32] [D_A Loss: 0.0248] [D_B Loss: 0.0405] [G Loss: 4.6400]
# [Epoch 115/200] [Batch 0/32] [D_A Loss: 0.0432] [D_B Loss: 0.0587] [G Loss: 5.0218]
# [Epoch 116/200] [Batch 0/32] [D_A Loss: 0.0292] [D_B Loss: 0.0435] [G Loss: 5.4247]
# [Epoch 117/200] [Batch 0/32] [D_A Loss: 0.0363] [D_B Loss: 0.0372] [G Loss: 5.2598]
# [Epoch 118/200] [Batch 0/32] [D_A Loss: 0.0293] [D_B Loss: 0.0262] [G Loss: 4.9880]
# [Epoch 119/200] [Batch 0/32] [D_A Loss: 0.0749] [D_B Loss: 0.1707] [G Loss: 4.9115]
# [Epoch 120/200] [Batch 0/32] [D_A Loss: 0.0494] [D_B Loss: 0.0284] [G Loss: 4.4487]
# [Epoch 121/200] [Batch 0/32] [D_A Loss: 0.0327] [D_B Loss: 0.0281] [G Loss: 4.8085]
# [Epoch 122/200] [Batch 0/32] [D_A Loss: 0.2063] [D_B Loss: 0.0616] [G Loss: 4.1297]
# [Epoch 123/200] [Batch 0/32] [D_A Loss: 0.0344] [D_B Loss: 0.0361] [G Loss: 5.1772]
# [Epoch 124/200] [Batch 0/32] [D_A Loss: 0.0373] [D_B Loss: 0.0559] [G Loss: 4.3883]
# [Epoch 125/200] [Batch 0/32] [D_A Loss: 0.0319] [D_B Loss: 0.0335] [G Loss: 5.0291]
# [Epoch 126/200] [Batch 0/32] [D_A Loss: 0.0334] [D_B Loss: 0.0309] [G Loss: 5.1662]
# [Epoch 127/200] [Batch 0/32] [D_A Loss: 0.0376] [D_B Loss: 0.0560] [G Loss: 4.5934]
# [Epoch 128/200] [Batch 0/32] [D_A Loss: 0.0421] [D_B Loss: 0.0301] [G Loss: 4.7515]
# [Epoch 129/200] [Batch 0/32] [D_A Loss: 0.0318] [D_B Loss: 0.0554] [G Loss: 5.2169]
# [Epoch 130/200] [Batch 0/32] [D_A Loss: 0.0415] [D_B Loss: 0.0353] [G Loss: 5.3776]
# [Epoch 131/200] [Batch 0/32] [D_A Loss: 0.0490] [D_B Loss: 0.0469] [G Loss: 4.4797]
# [Epoch 132/200] [Batch 0/32] [D_A Loss: 0.0326] [D_B Loss: 0.0287] [G Loss: 4.8681]
# [Epoch 133/200] [Batch 0/32] [D_A Loss: 0.1363] [D_B Loss: 0.0230] [G Loss: 4.6568]
# [Epoch 134/200] [Batch 0/32] [D_A Loss: 0.0413] [D_B Loss: 0.0256] [G Loss: 4.8190]
# [Epoch 135/200] [Batch 0/32] [D_A Loss: 0.0455] [D_B Loss: 0.2339] [G Loss: 4.2594]
# [Epoch 136/200] [Batch 0/32] [D_A Loss: 0.0290] [D_B Loss: 0.0416] [G Loss: 4.6767]
# [Epoch 137/200] [Batch 0/32] [D_A Loss: 0.0290] [D_B Loss: 0.0484] [G Loss: 4.5544]
# [Epoch 138/200] [Batch 0/32] [D_A Loss: 0.0416] [D_B Loss: 0.0229] [G Loss: 4.7225]
# [Epoch 139/200] [Batch 0/32] [D_A Loss: 0.0243] [D_B Loss: 0.0209] [G Loss: 4.9742]
# [Epoch 140/200] [Batch 0/32] [D_A Loss: 0.0328] [D_B Loss: 0.0151] [G Loss: 4.8022]
# [Epoch 141/200] [Batch 0/32] [D_A Loss: 0.0202] [D_B Loss: 0.0205] [G Loss: 4.7093]
# [Epoch 142/200] [Batch 0/32] [D_A Loss: 0.0403] [D_B Loss: 0.0317] [G Loss: 4.8451]
# [Epoch 143/200] [Batch 0/32] [D_A Loss: 0.0265] [D_B Loss: 0.0178] [G Loss: 4.6902]
# [Epoch 144/200] [Batch 0/32] [D_A Loss: 0.0233] [D_B Loss: 0.0341] [G Loss: 4.7052]
# [Epoch 145/200] [Batch 0/32] [D_A Loss: 0.0339] [D_B Loss: 0.0343] [G Loss: 4.7094]
# [Epoch 146/200] [Batch 0/32] [D_A Loss: 0.0301] [D_B Loss: 0.0312] [G Loss: 4.8608]
# [Epoch 147/200] [Batch 0/32] [D_A Loss: 0.0418] [D_B Loss: 0.0302] [G Loss: 4.3422]
# [Epoch 148/200] [Batch 0/32] [D_A Loss: 0.0422] [D_B Loss: 0.0503] [G Loss: 5.1479]
# [Epoch 149/200] [Batch 0/32] [D_A Loss: 0.0458] [D_B Loss: 0.0321] [G Loss: 4.5388]
# [Epoch 150/200] [Batch 0/32] [D_A Loss: 0.0992] [D_B Loss: 0.0458] [G Loss: 4.2238]
# [Epoch 151/200] [Batch 0/32] [D_A Loss: 0.0690] [D_B Loss: 0.0422] [G Loss: 4.6238]
# [Epoch 152/200] [Batch 0/32] [D_A Loss: 0.0436] [D_B Loss: 0.0856] [G Loss: 4.8147]
# [Epoch 153/200] [Batch 0/32] [D_A Loss: 0.0324] [D_B Loss: 0.0402] [G Loss: 4.5561]
# [Epoch 154/200] [Batch 0/32] [D_A Loss: 0.0233] [D_B Loss: 0.0469] [G Loss: 4.4963]
# [Epoch 155/200] [Batch 0/32] [D_A Loss: 0.0194] [D_B Loss: 0.0281] [G Loss: 4.8519]
# [Epoch 156/200] [Batch 0/32] [D_A Loss: 0.0368] [D_B Loss: 0.0714] [G Loss: 4.2531]
# [Epoch 157/200] [Batch 0/32] [D_A Loss: 0.0334] [D_B Loss: 0.0402] [G Loss: 4.3244]
# [Epoch 158/200] [Batch 0/32] [D_A Loss: 0.0222] [D_B Loss: 0.0209] [G Loss: 4.8019]
# [Epoch 159/200] [Batch 0/32] [D_A Loss: 0.0181] [D_B Loss: 0.0258] [G Loss: 4.7793]
# [Epoch 160/200] [Batch 0/32] [D_A Loss: 0.0318] [D_B Loss: 0.0256] [G Loss: 4.7197]
# [Epoch 161/200] [Batch 0/32] [D_A Loss: 0.0418] [D_B Loss: 0.0357] [G Loss: 5.0333]
# [Epoch 162/200] [Batch 0/32] [D_A Loss: 0.0425] [D_B Loss: 0.0375] [G Loss: 5.0975]
# [Epoch 163/200] [Batch 0/32] [D_A Loss: 0.0709] [D_B Loss: 0.0266] [G Loss: 4.9334]
# [Epoch 164/200] [Batch 0/32] [D_A Loss: 0.0359] [D_B Loss: 0.0685] [G Loss: 5.2694]
# [Epoch 165/200] [Batch 0/32] [D_A Loss: 0.0236] [D_B Loss: 0.0382] [G Loss: 4.6149]
# [Epoch 166/200] [Batch 0/32] [D_A Loss: 0.0708] [D_B Loss: 0.0183] [G Loss: 4.6656]
# [Epoch 167/200] [Batch 0/32] [D_A Loss: 0.0313] [D_B Loss: 0.0816] [G Loss: 4.1886]
# [Epoch 168/200] [Batch 0/32] [D_A Loss: 0.0237] [D_B Loss: 0.0260] [G Loss: 4.5807]
# [Epoch 169/200] [Batch 0/32] [D_A Loss: 0.0496] [D_B Loss: 0.0388] [G Loss: 4.7584]
# [Epoch 170/200] [Batch 0/32] [D_A Loss: 0.0359] [D_B Loss: 0.0613] [G Loss: 4.6328]
# [Epoch 171/200] [Batch 0/32] [D_A Loss: 0.0415] [D_B Loss: 0.0418] [G Loss: 4.5286]
# [Epoch 172/200] [Batch 0/32] [D_A Loss: 0.0352] [D_B Loss: 0.0245] [G Loss: 4.8043]
# [Epoch 173/200] [Batch 0/32] [D_A Loss: 0.0235] [D_B Loss: 0.0297] [G Loss: 5.0134]
# [Epoch 174/200] [Batch 0/32] [D_A Loss: 0.0370] [D_B Loss: 0.0227] [G Loss: 5.2799]
# [Epoch 175/200] [Batch 0/32] [D_A Loss: 0.0420] [D_B Loss: 0.0377] [G Loss: 4.4306]
# [Epoch 176/200] [Batch 0/32] [D_A Loss: 0.0335] [D_B Loss: 0.0473] [G Loss: 5.0860]
# [Epoch 177/200] [Batch 0/32] [D_A Loss: 0.0390] [D_B Loss: 0.0300] [G Loss: 4.7936]
# [Epoch 178/200] [Batch 0/32] [D_A Loss: 0.0448] [D_B Loss: 0.0438] [G Loss: 4.3781]
# [Epoch 179/200] [Batch 0/32] [D_A Loss: 0.0328] [D_B Loss: 0.0352] [G Loss: 4.5309]
# [Epoch 180/200] [Batch 0/32] [D_A Loss: 0.0316] [D_B Loss: 0.0233] [G Loss: 4.5832]
# [Epoch 181/200] [Batch 0/32] [D_A Loss: 0.1745] [D_B Loss: 0.0332] [G Loss: 4.0295]
# [Epoch 182/200] [Batch 0/32] [D_A Loss: 0.0273] [D_B Loss: 0.0267] [G Loss: 4.4681]
# [Epoch 183/200] [Batch 0/32] [D_A Loss: 0.0405] [D_B Loss: 0.0571] [G Loss: 4.7711]
# [Epoch 184/200] [Batch 0/32] [D_A Loss: 0.0241] [D_B Loss: 0.0350] [G Loss: 4.7571]
# [Epoch 185/200] [Batch 0/32] [D_A Loss: 0.0253] [D_B Loss: 0.0234] [G Loss: 4.7810]
# [Epoch 186/200] [Batch 0/32] [D_A Loss: 0.0288] [D_B Loss: 0.0239] [G Loss: 4.6495]
# [Epoch 187/200] [Batch 0/32] [D_A Loss: 0.0362] [D_B Loss: 0.0161] [G Loss: 4.4558]
# [Epoch 188/200] [Batch 0/32] [D_A Loss: 0.0315] [D_B Loss: 0.0146] [G Loss: 4.6971]
# [Epoch 189/200] [Batch 0/32] [D_A Loss: 0.0370] [D_B Loss: 0.0209] [G Loss: 4.2660]
# [Epoch 190/200] [Batch 0/32] [D_A Loss: 0.0239] [D_B Loss: 0.0294] [G Loss: 4.7375]
# [Epoch 191/200] [Batch 0/32] [D_A Loss: 0.0302] [D_B Loss: 0.0254] [G Loss: 4.7919]
# [Epoch 192/200] [Batch 0/32] [D_A Loss: 0.1013] [D_B Loss: 0.0222] [G Loss: 4.0428]
# [Epoch 193/200] [Batch 0/32] [D_A Loss: 0.0498] [D_B Loss: 0.0482] [G Loss: 3.9833]
# [Epoch 194/200] [Batch 0/32] [D_A Loss: 0.0445] [D_B Loss: 0.0605] [G Loss: 4.0331]
# [Epoch 195/200] [Batch 0/32] [D_A Loss: 0.0278] [D_B Loss: 0.0517] [G Loss: 4.7062]
# [Epoch 196/200] [Batch 0/32] [D_A Loss: 0.0270] [D_B Loss: 0.0272] [G Loss: 4.8098]
# [Epoch 197/200] [Batch 0/32] [D_A Loss: 0.0218] [D_B Loss: 0.0295] [G Loss: 4.8778]
# [Epoch 198/200] [Batch 0/32] [D_A Loss: 0.0251] [D_B Loss: 0.0236] [G Loss: 4.6671]
# [Epoch 199/200] [Batch 0/32] [D_A Loss: 0.0228] [D_B Loss: 0.0246] [G Loss: 5.1226]

# %%
test_dataset = ImageDataset(path_to_dataset, transform=transform, mode='test', max_samples=5)
test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
def show_images(real, fake, title="Input vs Output"):
    real = real * 0.5 + 0.5
    fake = fake * 0.5 + 0.5

    images = torch.cat([real, fake], dim=3)
    grid = make_grid(images, nrow=1)

    np_img = grid.permute(1, 2, 0).detach().cpu().numpy()
    plt.figure(figsize=(6, 3))
    plt.imshow(np_img)
    plt.axis("off")
    plt.title(title)
    plt.show()

# %%
G_AB.eval()

with torch.no_grad():
    for i, batch in enumerate(test_loader):
        real_A = batch["A"].to(device)
        fake_B = G_AB(real_A)
        show_images(real_A, fake_B, title=f"Sample {i+1}")

# %%
#Changes
